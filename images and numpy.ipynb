# %%
import numpy as np
import matplotlib.pyplot as plt  # required only for notebook
# %matplotlib inline

# %%
from PIL import Image

# %%
pic = Image.open('DATA/00-puppy.jpg')

# %%
plt.imshow(pic)
pic_arr = np.asarray(pic) # converting to array

# %%
pic_arr.shape
# Out:
# (1300, 1950, 3)

# %%
plt.imshow(pic_arr)

# %%
# accessing only one channel
pic_red = pic_arr.copy()

# %%
# R G B
plt.imshow(pic_red[:,:,0])

# %%
plt.imshow(pic_red[:,:,1])

# %%
plt.imshow(pic_red[:,:,2])

# %%
plt.imshow(pic_red[:,:,1], cmap='gray')

# %%
pic_red[:,:,2] = 0

# %%
plt.imshow(pic_red)
