# %%
import cv2

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# reading images swith wrong path doesnot show error
img = cv2.imread('DATA/00-puppy.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (1300, 1950, 3)

# %%
plt.imshow(img) #opencv uses BGR

# %%
fix_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(fix_img)

# %%
img_gray = cv2.imread('DATA/00-puppy.jpg', cv2.IMREAD_GRAYSCALE)

# %%
img_gray.shape
# Out:
# (1300, 1950)

# %%
plt.imshow(img_gray,cmap='gray')

# %%
# resizing images
plt.imshow(fix_img)

# %%
fix_img.shape
# Out:
# (1300, 1950, 3)

# %%
new_img = cv2.resize(fix_img,(600,600))

# %%
plt.imshow(new_img)

# %%
new_img = cv2.resize(fix_img,(0,0),fix_img,0.8,0.8)

# %%
plt.imshow(new_img)

# %%
new_img = cv2.flip(fix_img,0)

# %%
plt.imshow(new_img)

# %%
type(fix_img)
# Out:
# numpy.ndarray

# %%
cv2.imwrite('TOTALLY_NEW.jpeg',fix_img)
# Out:
# True

# %%
fig = plt.figure(figsize=(2,2))
ax = fig.add_subplot(111)
ax.imshow(fix_img)
