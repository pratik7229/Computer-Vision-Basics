# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import numpy as np

# %%
img = cv2.imread('DATA/00-puppy.jpg')
while True:
    cv2.imshow('puppy',img)
    if cv2.waitKey(1) & 0xFF == 27:
        break
cv2.destroyAllWindows()

# %%
# drawing on images
blan_img = np.zeros(shape=(512,512,3), dtype=np.int16)

# %%
plt.imshow(blan_img)

# %%
# drawing a rectangele

a = cv2.rectangle(blan_img,(34,0), (510,150),(0,255,0),thickness=10)
plt.imshow(a)

# %%
cv2.circle(blan_img,(300,10),50,(0,255,0),10)
plt.imshow(blan_img)

# %%
cv2.line(blan_img,(400,400),(50,50),(255,0,0), 5)
plt.imshow(blan_img)

# %%
font = cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(blan_img,'hello',(10,500),font,4,(255,255,255),3,cv2.LINE_AA)
plt.imshow(blan_img)

# %%
blank_img = np.zeros(shape=(512,512,3),dtype=np.int16)

# %%
plt.imshow(blank_img)

# %%
# adding custom polygon
vertices = np.array([[100,300],[200,200], [400,400],[200,400]],dtype=np.int32)

# %%
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 400],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2))

# %%
vertices.shape
# Out:
# (4, 2)

# %%
pts.shape
# Out:
# (4, 1, 2)

# %%
cv2.polylines(blank_img,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(blank_img)

# %%
# drawing images using mouse
# using callbacks

img = np.zeros((512,512,3),np.int8)

# %%
def draw_circle(event,x,y,flags,param):
    if event == cv2.EVENT_LBUTTONDOWN:
        cv2.circle(img,(x,y),100, (0,255,0), -1)

cv2.namedWindow(winname='mouse')
cv2.setMouseCallback('mouse',draw_circle)


while True:
    cv2.imshow('mouse',img)
    if cv2.waitKey(20) & 0xFF == 27:
        break
cv2.destroyAllWindows()

# %%
def draw_circle(event,x,y,flags,param):
    if event == cv2.EVENT_LBUTTONDOWN:
        cv2.circle(img,(x,y),100, (0,255,0), -1)
    elif event == cv2.EVENT_RBUTTONDOWN:
        cv2.circle(img,(x,y),100, (0,255,0), -1)
        

cv2.namedWindow(winname='mouse')
cv2.setMouseCallback('mouse',draw_circle)


while True:
    cv2.imshow('mouse',img)
    if cv2.waitKey(20) & 0xFF == 27:
        break
cv2.destroyAllWindows()

# %%
drawing = False
ix,iy = -1,-1
def draw_rectangle(event,x,y,flags,param):
    global ix,iy,drawing
    if event == cv2.EVENT_LBUTTONDOWN:
        drawing = True
        ix,iy = x,y
    elif event == cv2.EVENT_MOUSEMOVE:
        if drawing:
            cv2.rectangle(img,(ix,iy),(x,y), (255,0,0), 5)
    
    elif event == cv2.EVENT_LBUTTONUP:
        drawing = False
        cv2.rectangle(img,(ix,iy),(x,y), (255,0,0), 5)
        
    

cv2.namedWindow(winname='mouse')
cv2.setMouseCallback('mouse',draw_rectangle)


while True:
    cv2.imshow('mouse',img)
    if cv2.waitKey(20) & 0xFF == 27:
        break
cv2.destroyAllWindows()
